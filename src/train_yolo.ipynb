# %% [markdown]
# # YOLOv8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  # !nvidia-smi
# Out:
# Sun Sep 28 05:52:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=dataset/data.yaml epochs=30 imgsz=640 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ### Evaluate and inference

# %%
from IPython.display import display, Image

# %%
Image(filename=f'runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'runs/detect/train/results.png', width=600)

# %%
Image(filename=f'runs/detect/train/val_batch2_pred.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source='/content/drive/MyDrive/helmet_detection/dataset/test/images/000015_jpg.rf.2240f9564d3f5e981098efdc6c5eda8f.jpg'

# %%
image_path = "/content/drive/MyDrive/helmet_detection/runs/detect/predict2/000015_jpg.rf.2240f9564d3f5e981098efdc6c5eda8f.jpg"
display(Image(filename=image_path, width=600))

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/helmet_detection/runs/detect/train/weights/best.pt data=dataset/data.yaml
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 29.3±6.0 MB/s, size: 57.2 KB)
# val: Scanning /content/drive/MyDrive/helmet_detection/dataset/valid/labels.cache... 777 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 777/777 10.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 49/49 3.1it/s 15.8s
#                    all        777      12508      0.931      0.886      0.939      0.593
#                 helmet        327        999      0.937      0.869      0.929      0.688
#              no_helmet        483      11509      0.925      0.903      0.948      0.498
# Speed: 0.7ms preprocess, 8.3ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /content/drive/MyDrive/helmet_detection/runs/detect/val
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/helmet_detection/runs/detect/train/weights/best.pt data=dataset/data.yaml split=test
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 1.1±1.2 ms, read: 6.0±1.3 MB/s, size: 49.9 KB)
# val: Scanning /content/drive/MyDrive/helmet_detection/dataset/test/labels... 757 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 757/757 81.5it/s 9.3s
# val: New cache created: /content/drive/MyDrive/helmet_detection/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 3.8it/s 12.7s
#                    all        757      12260      0.927      0.834      0.893      0.574
#                 helmet        300        875      0.918      0.774      0.837      0.645
#              no_helmet        495      11385      0.937      0.894      0.949      0.502
# Speed: 1.0ms preprocess, 8.5ms inference, 0.0ms loss, 2.2ms postprocess per image
# ...

# %%
# !yolo export model=/content/drive/MyDrive/helmet_detection/runs/detect/train/weights/best.pt format=onnx
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/helmet_detection/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (21.5 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim>=0.1.67', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 2.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.19.1rc1 opset 22...
# ONNX: slimming with onnxslim 0.1.69...
# ONNX: export success ✅ 5.0s, saved as '/content/drive/MyDrive/helmet_detection/runs/detect/train/weights/best.onnx' (42.7 MB)
#
# ...
